# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.bronze_customer_data
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_landing_volume/customer_data.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
